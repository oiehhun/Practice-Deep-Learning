# %%
import pandas as pd
import numpy as np

# %%
with open('2016_filtered_review.txt', encoding='utf-8') as f:
    docs = [doc.strip().split('\t\t') for doc in f]
    docs = [(doc[1], int(doc[2])) for doc in docs if len(doc) == 3]
    # To read the second and third column info from each row
    texts, scores = zip(*docs[:20000])
    # 둘을 분리해서 별도의 list 변수로 저장

# %%
filtered_texts = []
filtered_labels = []

for text, score in zip(texts, scores):
    if 5 <= score <= 9:
        continue
        
    # 평점 기준으로 문서에 label을 부여
    # 1 ~ 3 -> 부정, 0
    # 9 ~ 10 -> 긍정, 1
    filtered_texts.append(text)
    filtered_labels.append(1 if score > 9 else 0)

# %%
sum(filtered_labels)/len(filtered_texts)
# Out:
# 0.8294408520349943

# %%
filtered_texts[0]
# Out:
# ' 진심 쓰레기 영화 만들 무서 알 쫄아 틀었 이건 뭐 웃 거리 없는 쓰레기 영화 임'

# %%
filtered_texts[:2]
# Out:
# [' 진심 쓰레기 영화 만들 무서 알 쫄아 틀었 이건 뭐 웃 거리 없는 쓰레기 영화 임',
#  ' 역대 좀비 영화 가장 최고다 원작 만화 읽어 보려 영화 보고 결정 하려 감독 간츠 실사 했 사람 거르려 그냥 봤 정말 흠잡 없는 최고 좀비 영화 잔인 거 싫어하지 참고 볼 만하 로미 인물 왜 그런 모르']

# %%
filtered_words = [doc.strip().split() for doc in filtered_texts]

# %%
total_words = []
for words in filtered_words:
    total_words.extend(words)

# %%
print(len(total_words))
print(len(set(total_words)))
# Out:
# 153375
# 13909

# %%
from collections import Counter
c = Counter(total_words)

# %%
max_features = 5000 # 빈도수를 기준으로 상위 5000개의 단어만 사용
common_words = [ word for word, count in c.most_common(max_features)]

# %%
len(common_words)
# Out:
# 5000

# %%
print(common_words)
# Out:
# ['영화', '너무', '좋', '봤', '보고', '정말', '연기', '감동', '배우', '진짜', '대통령', '였', '사람', '했', '입니', '것', '먹', '그', '더', '노무현', '이', '그립', '눈물', '보는', '잘', '수', '생각', '가슴', '하는', '분', '마음', '꼭', '봐', '현실', '알', '이런', '최고', '볼', '우리', '때', '있는', '다시', '본', '할', '스토리', '역사', '나', '말', '같은', '좀비', '그냥', '아니', '같아', '보면', '없는', '여운', '시간', '평점', '또', '청춘', '내', '역시', '한번', '울었', '지금', '이었', '많은', '살', '재미', '어른', '점', '이야기', '순정', '있었', '마지막', '내용', '들', '아이', '왜', '한', '친구', '처음', '되', '짱구', '내내', '울', '하게', '재밌게', '된', '슬프', '왔', '공유', '그런', '참', '사랑', '모습', '되는', '장면', '함', '기대', '재밌었', '원피스', '같다', '거', '보러', '저', '국민', '보세', '극장판', '하나', '있', '모르', '좀', '합', '인간', '넘', '손예진', '느낌', '와', '정도', '감사합', '모두', '끝', '인생', '일본', '감정', '당신', '감독', '너무나', '않고', '안', '돈', '덕혜옹주', '재밌어', '아닌', '같', '짱', '듯', '요즘', '세상', '일', '나라', '전도연', '속', '시대', '보기', '부산', '남', '순수한', '계속', '못', '펑펑', '완전', '
'소름', '전혀', '교훈', '깊게', '대사', '깊은', '성공', '받고', '해준', '응원', '존경합', '시민', '웃고', '재미있어', '자', '까', '음', '해지', '쓸', '뿐', '첫', '캐릭터', '만', '짜증', '온', '하기', '후반', '멜로', '굳', '야하는', '어린', '상식', '무', '의', '현재', '생각했', '흘리', '쓰', '쉽', '주연', '받았', '사랑해', '남네', '조선', '갈', '절대', '드라마', '시작', '잘한', '용기', '싶었', '나고', '담', '있게', '깊었', '국가대표', '받아', '점도', '시리즈', '바로', '가서', '현', '없네', '버린', '아까운', '반전', '나서', '등', '로', '치', '순수함', '드는', '많아', '신', '뭘', '스럽', '버리', '아까', '받', '책', '행보', '예고편', '재미있다', '니', '누가', '많았', '매력', '부', '바보', '얘기', '지루하지', '언제', '매우', '여기', '답', '맞는', '따', '를', '이지', '바람', '부모님', '짠', '절절', '정치인', '노무', '줬', '씁', '버렸', '생각합', '최근', '문제', '하며', '막', '이기', '아닐', '잘해서', '간', '딸', '지수', '예쁜', '재미있', '잘하고', '저런', '있지', '명작', '행복했', '싶네', '그리움', '친일파', '짜', '길', '안되는', '아니었', '뜻', '박수', '백', '힘든', '남녀', '자리', '웃다', '기모', '들이', '다운', '다르', '깊이', '이후', '갈수록', '시키', '편', '과거', '포기하지', '잘해', '청춘영화', '드리', '유치', '는', '철학', '재밌네', '같았', '기대했', '야한', '웃기', '그녀', '허무', '중요한', '집', '즐겁', '물론', '표현한', '나중', '흘렸', '감명', '정선', '운', '있으', '느껴지는', '띠' ...

# %%
words_dic ={}  # 각 단어에 index 번호 부여
words_index_dic={} # index 번호가 key가 됨, value는 단어
for index, word in enumerate(common_words):
    words_dic[word]=index
    words_index_dic[index]=word

# %%
filtered_indexed_words = [] # index 번호가 부여된 단어들만을 사용해서 각 문서를 표현
for review in filtered_words:
    indexed_words=[]
    for word in review:
        try:
            indexed_words.append(words_dic[word])
        except: 
            pass
    filtered_indexed_words.append(indexed_words)

# %%
filtered_indexed_words[0] # 첫번째 영화 리뷰에 사용된 단어들의 인덱스
# Out:
# [227, 349, 0, 319, 34, 225, 182, 1050, 811, 54, 349, 0, 185]

# %%
# 어떠한 단어들인지 확인
[words_index_dic[index] for index in filtered_indexed_words[0]]
# Out:
# ['진심', '쓰레기', '영화', '만들', '알', '이건', '뭐', '웃', '거리', '없는', '쓰레기', '영화', '임']

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(filtered_indexed_words, filtered_labels, test_size=0.2)

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=max_features):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    # len(sequences) => number of documents
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences): # sequence => 단어들의 index로 구성되어 있는 리스트
        results[i, sequence] = 1.  # set specific indices of results[i] to 1s
    return results

# %%
X_train_indexed = vectorize_sequences(X_train)
X_test_indexed = vectorize_sequences(X_test)

# %%
X_train_indexed[0]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
len(X_train_indexed[0])
# Out:
# 5000

# %%
X_train_indexed.shape
# Out:
# (10516, 5000)

# %%
y_train[0]
# Out:
# 1

# %%
from tensorflow.keras.utils import to_categorical
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# %%
y_train_one_hot[0]
# Out:
# array([0., 1.], dtype=float32)

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Dense(32, activation='relu', input_shape=(max_features,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(2, activation='softmax'))

# %%
from tensorflow.keras.optimizers import RMSprop
model.compile(optimizer=RMSprop(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
X_train_indexed.shape
# Out:
# (10516, 5000)

# %%
history = model.fit(X_train_indexed, y_train_one_hot, epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10
# 66/66 [==============================] - 1s 5ms/step - loss: 0.5065 - accuracy: 0.8124 - val_loss: 0.3607 - val_accuracy: 0.8531
# Epoch 2/10
# 66/66 [==============================] - 0s 3ms/step - loss: 0.2764 - accuracy: 0.8925 - val_loss: 0.2424 - val_accuracy: 0.9092
# Epoch 3/10
# 66/66 [==============================] - 0s 4ms/step - loss: 0.1857 - accuracy: 0.9290 - val_loss: 0.2237 - val_accuracy: 0.9106
# Epoch 4/10
# 66/66 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9442 - val_loss: 0.2209 - val_accuracy: 0.9168
# Epoch 5/10
# 66/66 [==============================] - 0s 4ms/step - loss: 0.1207 - accuracy: 0.9527 - val_loss: 0.2312 - val_accuracy: 0.9178
# Epoch 6/10
# 66/66 [==============================] - 0s 4ms/step - loss: 0.1042 - accuracy: 0.9604 - val_loss: 0.2482 - val_accuracy: 0.9187
# Epoch 7/10
# 66/66 [==============================] - 0s 4ms/step - loss: 0.0917 - accuracy: 0.9661 - val_loss: 0.2593 - val_accuracy: 0.9211
# Epoch 8/10
# 66/66 [==============================] - 0s 4ms/step - loss: 0.0817 - accuracy: 0.9704 - val_loss: 0.2750 - val_accuracy: 0.9178
# Epoch 9/10
# 66/66 [==============================] - 0s 4ms/step - loss: 0.0732 - accuracy: 0.9737 - val_loss: 0.2837 - val_accuracy: 0.9130
# Epoch 10/10
# 66/66 [==============================] - 0s 4ms/step - loss: 0.0669 - accuracy: 0.9769 - val_loss: 0.3066 - val_accuracy: 0.9159

# %%
test_loss, test_acc = model.evaluate(X_test_indexed, y_test_one_hot)
print('test_acc:', test_acc)
# Out:
# 83/83 [==============================] - 0s 705us/step - loss: 0.2981 - accuracy: 0.9140
# test_acc: 0.9140357375144958

# %%
len(X_test[0])
# Out:
# 16

# %%
model.predict(X_test_indexed)[:40]
# Out:
# array([[7.75632322e-01, 2.24367633e-01],
#        [9.37626045e-03, 9.90623772e-01],
#        [3.70502597e-08, 1.00000000e+00],
#        [5.32671763e-03, 9.94673312e-01],
#        [3.86480824e-03, 9.96135235e-01],
#        [2.69148018e-06, 9.99997258e-01],
#        [2.63371654e-02, 9.73662853e-01],
#        [2.51541939e-02, 9.74845827e-01],
#        [3.09321168e-03, 9.96906817e-01],
#        [3.72912854e-01, 6.27087176e-01],
#        [8.64512622e-01, 1.35487333e-01],
#        [2.50578509e-04, 9.99749362e-01],
#        [1.21169156e-04, 9.99878764e-01],
#        [1.91863105e-02, 9.80813682e-01],
#        [6.58653909e-03, 9.93413508e-01],
#        [8.70946273e-02, 9.12905395e-01],
#        [1.18157901e-01, 8.81842136e-01],
#        [9.17396069e-01, 8.26039836e-02],
#        [6.22274383e-05, 9.99937773e-01],
#        [1.28223617e-02, 9.87177610e-01],
#        [1.69623315e-01, 8.30376685e-01],
#        [3.48543283e-04, 9.99651432e-01],
#        [4.19936939e-08, 1.00000000e+00],
#        [8.44086893e-03, 9.91559148e-01],
#        [2.14142740e-01, 7.85857260e-01],
#        [4.36011329e-03, 9.95639920e-01],
#        [8.96883786e-01, 1.03116207e-01],
#        [1.84946202e-05, 9.99981523e-01],
#        [8.30184937e-01, 1.69815078e-01],
#        [4.66930727e-03, 9.95330691e-01],
#        [2.01300114e-01, 7.98699915e-01],
#        [8.14276636e-01, 1.85723364e-01],
#        [9.07281518e-01, 9.27184597e-02],
#        [3.98250446e-02, 9.60174978e-01],
#        [4.80368137e-01, 5.19631863e-01],
#        [1.04097584e-02, 9.89590228e-01],
#        [5.15296335e-07, 9.99999523e-01],
#        [5.76000288e-02, 9.42399919e-01],
#        [7.87643614e-07, 9.99999166e-01],
#        [2.05222234e-01, 7.94777811e-01]], dtype=float32)

# %%
c = 0
for k in model.predict(X_test_indexed):
    if k[0]>0.5:
        print(c, k)
    c=c+1
# Out:
# 3 [0.9047961  0.09520394]
# 6 [0.5247267  0.47527328]
# 10 [0.6331061  0.36689386]
# 12 [0.62674105 0.37325892]
# 13 [0.7420787  0.25792122]
# 16 [0.6575557  0.34244433]
# 43 [0.778568   0.22143193]
# 59 [0.8863832  0.11361685]
# 71 [0.7523109 0.2476891]
# 80 [0.5487035 0.4512965]
# 84 [0.6115333  0.38846675]
# 93 [0.8807358  0.11926413]
# 99 [0.5061654  0.49383458]
# 113 [0.6199672 0.3800328]
# 116 [0.56640685 0.4335931 ]
# 123 [0.6748398  0.32516024]
# 127 [0.61390644 0.38609356]
# 139 [0.6701604  0.32983953]
# 140 [0.8101536  0.18984644]
# 141 [0.50548345 0.49451655]
# 142 [0.6648758 0.3351242]
# 146 [0.62297606 0.377024  ]
# 147 [0.79124606 0.20875391]
# 154 [0.8020519  0.19794813]
# 156 [0.63310015 0.36689985]
# 163 [0.67738444 0.32261556]
# 167 [0.52910376 0.4708962 ]
# 169 [0.5600746  0.43992537]
# 173 [0.86147475 0.13852525]
# 181 [0.70006937 0.29993063]
# 196 [0.58235735 0.41764268]
# 200 [0.53249425 0.4675057 ]
# 202 [0.54691887 0.45308113]
# 206 [0.91363126 0.08636871]
# 207 [0.76142865 0.23857136]
# 216 [0.76880515 0.23119493]
# 218 [0.8315142  0.16848579]
# 226 [0.77246684 0.22753319]
# 230 [0.6646466  0.33535337]
# 235 [0.689765 0.310235]
# 239 [0.5751196  0.42488047]
# 241 [0.90433425 0.09566571]
# 250 [0.5519707 0.4480293]
# 255 [0.6419818  0.35801816]
# 258 [0.8792084  0.12079164]
# 265 [0.77189815 0.22810186]
# 267 [0.5706018 0.4293982]
# 277 [0.79468834 0.20531161]
# 283 [0.5040686  0.49593142]
# 290 [0.6519958 0.3480042]
# 294 [0.79600364 0.2039964 ]
# 309 [0.50743043 0.49256948]
# 320 [0.61552835 0.38447165]
# 325 [0.54364145 0.45635852]
# 338 [0.688721 0.311279]
# 340 [0.5069272 0.4930728]
# 346 [0.66091883 0.33908114]
# 360 [0.54521275 0.45478734]
# 361 [0.6667476 0.3332524]
# 368 [0.8203341  0.17966594]
# 389 [0.50208384 0.4979162 ]
# 398 [0.694502   0.30549803]
# 407 [0.8151276  0.18487239]
# 409 [0.5613254 0.4386746]
# 413 [0.58485603 0.415144  ]
# 420 [0.5662635 0.4337365]
# 435 [0.69243115 0.3075689 ]
# 442 [0.7766575  0.22334245]
# 455 [0.5927703  0.40722975]
# 457 [0.85111827 0.14888169]
# 465 [0.51589495 0.48410502]
# 469 [0.6550599  0.34494016]
# 495 [0.59306616 0.40693387]
# 499 [0.79276896 0.207231  ]
# 511 [0.7474682  0.25253186]
# 512 [0.51484597 0.485154  ]
# 516 [0.70603794 0.2939621 ]
# 517 [0.6659234 0.3340766]
# 522 [0.762476   0.23752399]
# 550 [0.878457   0.12154298]
# 553 [0.5676918  0.43230823]
# 566 [0.8561151  0.14388484]
# 567 [0.62820756 0.37179244]
# 580 [0.7706346  0.22936542]
# 590 [0.5323608  0.46763918]
# 593 [0.6217969 0.3782031]
# 612 [0.92889744 0.0711026 ]
# 639 [0.63466555 0.36533442]
# 644 [0.7463672  0.25363278]
# 648 [0.790916   0.20908396]
# 649 [0.5886468 0.4113532]
# 650 [0.73004013 0.26995984]
# 656 [0.80638623 0.19361375]
# 659 [0.95539427 0.0446057 ]
# 664 [0.54710895 0.452891  ]
# 667 [0.8760572 0.1239428]
# 681 [0.5486932  0.45130682]
# 686 [0.6163307  0.38366935]
# 693 [0.667533   0.33246702]
# 707 [0.7614999  0.23850009]
# 708 [0.5529039 0.4470961]
# 709 [0.8853486 0.1146514]
# 711 [0.8784745  0.12152551]
# 714 [0.6231375 0.3768625]
# 721 [0.59068364 0.40931636]
# 722 [0.7564513  0.24354862]
# 728 [0.6403214 0.3596786]
# 730 [0.74510115 0.25489882]
# 731 [0.6589604  0.34103957]
# 733 [0.85285133 0.14714868]
# 740 [0.84810275 0.15189731]
# 759 [0.71250004 0.28749996]
# 767 [0.5793037  0.42069632]
# 781 [0.58769184 0.4123081 ]
# 787 [0.680572   0.31942794]
# 811 [0.8385302  0.16146982]
# 820 [0.5266183  0.47338167]
# 822 [0.7213704 0.2786296]
# 825 [0.84765846 0.1523415 ]
# 827 [0.6729577  0.32704228]
# 837 [0.5776577  0.42234227]
# 843 [0.8728411  0.12715888]
# 853 [0.6457462  0.35425383]
# 863 [0.5763851  0.42361492]
# 865 [0.68185854 0.3181415 ]
# 871 [0.5658276 0.4341724]
# 872 [0.5098104  0.49018958]
# 885 [0.78679925 0.21320075]
# 893 [0.7439022  0.25609782]
# 900 [0.6653733 0.3346267]
# 903 [0.84276897 0.15723103]
# 911 [0.7705147  0.22948521]
# 915 [0.6574176 0.3425824]
# 916 [0.8256242  0.17437574]
# 918 [0.7574832  0.24251679]
# 932 [0.50564295 0.4943571 ]
# 960 [0.57304305 0.4269569 ]
# 965 [0.5949706  0.40502942]
# 966 [0.7525077  0.24749234]
# 975 [0.57472247 0.4252775 ]
# 978 [0.5070959  0.49290413]
# 979 [0.7332366  0.26676336]
# 1001 [0.58107716 0.4189228 ]
# 1003 [0.9225603  0.07743976]
# 1005 [0.6233903  0.37660974]
# 1009 [0.6116921 0.3883079]
# 1012 [0.57407004 0.42593   ]
# 1022 [0.8875162  0.11248377]
# 1037 [0.554401 0.445599]
# 1041 [0.6191438  0.38085628]
# 1052 [0.74426854 0.25573152]
# 1056 [0.8044552  0.19554473]
# 2238 [0.93576884 0.06423116]
# 2239 [0.67721224 0.3227878 ]
# 2253 [0.7273054 0.2726946]
# 2275 [0.667192   0.33280802]
# 2285 [0.60310924 0.39689073]
# 2287 [0.69666487 0.30333513]
# 2291 [0.7007116 0.2992884]
# 2293 [0.5193659  0.48063406]
# 2294 [0.7672419 0.2327581]
# 2296 [0.6558748  0.34412527]
# 2312 [0.76662874 0.23337129]
# 2317 [0.60280037 0.39719963]
# 2320 [0.5713519 0.4286481]
# 2323 [0.7292074 0.2707926]
# 2336 [0.9699434  0.03005663]
# 2349 [0.6112463 0.3887537]
# 2359 [0.6491298  0.35087016]
# 2367 [0.77423865 0.22576131]
# 2371 [0.7547806 0.2452194]
# 2381 [0.77524805 0.22475196]
# 2388 [0.8254637  0.17453633]
# 2392 [0.8126222  0.18737781]
# 2394 [0.79657024 0.20342973]
# 2407 [0.60254353 0.39745647]
# 2411 [0.86372715 0.13627282]
# 2413 [0.5560939 0.4439062]
# 2417 [0.8144718 0.1855282]
# 2428 [0.72632277 0.27367726]
# 2431 [0.80950135 0.1904987 ]
# 2434 [0.5015673  0.49843264]
# 2438 [0.77024126 0.22975872]
# 2462 [0.50925404 0.49074596]
# 2474 [0.66104126 0.33895874]
# 2478 [0.50263387 0.49736613]
# 2487 [0.6113554  0.38864464]
# 2489 [0.8594276  0.14057246]
# 2490 [0.68362635 0.31637365]
# 2515 [0.8622411  0.13775893]
# 2517 [0.8691216  0.13087842]
# 2522 [0.9579745 0.0420255]
# 2523 [0.5031194  0.49688053]
# 2526 [0.6767031  0.32329687]
# 2537 [0.7839043 0.2160957]
# 2547 [0.7266015  0.27339852]
# 2553 [0.69083    0.30917004]
# 2567 [0.56341755 0.43658248]
# 2571 [0.9088042  0.09119579]
# 2576 [0.76217043 0.2378295 ]
# 2578 [0.5117192  0.48828074]
# 2579 [0.7321363  0.26786366]
# 2604 [0.65428644 0.3457136 ]
# 2609 [0.52067095 0.47932902]
# 2614 [0.5697011 0.4302989]
# 2623 [0.87177974 0.12822032]
# 2627 [0.9102894  0.08971065]
# 2633 [0.73574567 0.26425433]
# 2638 [0.61328    0.38672003]
# 2642 [0.5929323  0.40706775]
# 2645 [0.86958903 0.13041092]
# 2648 [0.69118315 0.3088168 ]
# 2650 [0.6084483 0.3915516]
# 2659 [0.710315   0.28968507]
# 2662 [0.77312547 0.22687455]
# 2669 [0.6638202  0.33617982]
# 2672 [0.56704533 0.4329547 ]
# 2681 [0.60902727 0.39097276]
# 2688 [0.5442826 0.4557174]
# 2690 [0.6833708  0.31662914]
# 2691 [0.9362648  0.06373512]
# 2693 [0.80969524 0.19030477]
# 2702 [0.5178024  0.48219755]
# 2706 [0.5201698  0.47983015]
# 2719 [0.6115014  0.38849857]
# 2732 [0.8976581  0.10234192]
# 2741 [0.75712836 0.24287172]
# 2749 [0.73017055 0.2698295 ]
# 2757 [0.5269074  0.47309268]
# 2765 [0.5243533  0.47564662]
# 2772 [0.66021216 0.3397879 ]
# 2794 [0.5552847  0.44471535]
# 2801 [0.52303636 0.47696364]
# 2807 [0.7215456 0.2784544]
# 2821 [0.5209168  0.47908315]
# 2822 [0.54200953 0.4579904 ]
# 2827 [0.51644945 0.4835505 ]
# 2830 [0.71751267 0.28248733]
# 2839 [0.6207363  0.37926373]
# 2845 [0.61320215 0.3867978 ]
# 2862 [0.83001584 0.16998419]
# 2865 [0.6296256  0.37037432]
# 2873 [0.5296147  0.47038528]
# 2876 [0.5019769 0.4980231]
# 2879 [0.7645553 0.2354447]
# 2882 [0.86073977 0.13926022]
# 2907 [0.94343954 0.05656045]
# 2914 [0.50428665 0.4957133 ]
# 2933 [0.8331257  0.16687424]
# 2944 [0.8382308  0.16176918]
# 2951 [0.6996823 0.3003177]
# 2965 [0.6954999  0.30450007]
# 2969 [0.5368393 0.4631607]
# 2970 [0.7694268  0.23057316]
# 2981 [0.7408203  0.25917974]
# 2985 [0.8085406  0.19145934]
# 2987 [0.84272826 0.15727176]
# 2988 [0.65295947 0.34704056]
# 2990 [0.90616465 0.09383532]
# 2991 [0.7128582 0.2871418]
# 2995 [0.71712863 0.28287137]
# 2998 [0.6031482  0.39685178]
# 2999 [0.6782523  0.32174772]
# 3013 [0.54955614 0.45044395]
# 3018 [0.62366414 0.37633592]
# 3019 [0.5818837  0.41811627]
# 3022 [0.5169523  0.48304772]
# 3026 [0.6037141  0.39628592]
# 3032 [0.7968392 0.2031608]
# 3033 [0.7614748  0.23852521]
# 3043 [0.7086722  0.29132777]
# 3046 [0.7375098 0.2624902]
# 3056 [0.73298424 0.26701578]
# 3069 [0.71670073 0.2832992 ]
# 3071 [0.65914565 0.34085438]
# 3081 [0.6390176  0.36098242]
# 3083 [0.83438766 0.16561233]
# 3107 [0.6952832  0.30471683]
# 3120 [0.50519335 0.49480665]
# 3124 [0.6116579 0.3883421]
# 3126 [0.55134696 0.44865307]
# 3141 [0.555737   0.44426295]
# 3168 [0.6345639  0.36543608]
# 3175 [0.6163914  0.38360855]
# 3182 [0.5608169 0.4391831]
# 3192 [0.5484264  0.45157358]
# 3194 [0.59116817 0.40883186]
# 3205 [0.5070547  0.49294534]
# 3216 [0.61991453 0.38008544]
# 3217 [0.70448714 0.29551288]
# 3218 [0.75529575 0.24470419]
# 3219 [0.5603487  0.43965134]
# 3224 [0.7226868  0.27731323]
# 3225 [0.5310078  0.46899214]
# 3228 [0.90298444 0.09701558]
# 3230 [0.54092187 0.4590781 ]
# 3244 [0.6772648  0.32273522]
# 3248 [0.8261317  0.17386834]
# 3259 [0.7820882  0.21791181]
# 3260 [0.69442934 0.3055706 ]
# 3262 [0.6310319 0.3689682]
# 3270 [0.5686066  0.43139338]
# 3278 [0.65446585 0.34553415]
# 3287 [0.63677424 0.36322576]
# 3295 [0.5405018  0.45949823]
# 3304 [0.5260821 0.4739179]
# 3307 [0.62719136 0.3728086 ]
# 3309 [0.91059154 0.08940847]
# 3327 [0.6601143 0.3398857]
# 3332 [0.78730726 0.21269271]
# 3340 [0.5742725  0.42572746]
# 3342 [0.6573036 0.3426964]
# 3350 [0.54294324 0.4570568 ]
# 3356 [0.7025436  0.29745638]
# 3364 [0.6942996 0.3057004]
# 3366 [0.85055524 0.14944479]
# 3368 [0.80602634 0.19397363]
# 3386 [0.5442469 0.4557531]
# 3387 [0.57645017 0.4235498 ]
# 3389 [0.59428346 0.40571657]
# 3391 [0.6036752  0.39632475]
# 3397 [0.5302508  0.46974924]
# 3410 [0.7197297  0.28027028]
# 3412 [0.94781595 0.05218402]
# 3414 [0.5306352  0.46936485]
# 3415 [0.560834   0.43916604]
# 3423 [0.5471825  0.45281747]
# 3429 [0.76809025 0.23190975]
# 3431 [0.53670096 0.46329907]
# 3433 [0.5231145 0.4768855]
# 3435 [0.6718453 0.3281547]
# 3446 [0.6419811  0.35801885]
# 3453 [0.51269805 0.48730192]
# 3455 [0.5486031  0.45139685]
# 3464 [0.59021616 0.4097838 ]
# 3467 [0.67521286 0.3247872 ]
# 3469 [0.686288   0.31371203]
# 3490 [0.6078133  0.39218673]
# 3492 [0.7543647  0.24563535]
# 3497 [0.6282779  0.37172207]
# 3500 [0.87863237 0.12136764]
# 3510 [0.52321607 0.47678387]
# 3514 [0.5625649  0.43743503]
# 3515 [0.8731581  0.12684193]
# 3518 [0.56046295 0.43953708]
# 3528 [0.80957836 0.1904216 ]
# 3534 [0.6972871  0.30271295]
# 3545 [0.7352992 0.2647008]
# 3554 [0.5191128 0.4808872]
# 3558 [0.67675924 0.32324076]
# 3568 [0.79498667 0.20501335]
# 3569 [0.5262773  0.47372267]
# 3571 [0.74031293 0.25968704]
# 3575 [0.524092 0.475908]
# 3596 [0.7192954  0.28070465]
# 3597 [0.67766744 0.3223326 ]
# 3606 [0.57504725 0.42495278]
# 3608 [0.5793534  0.42064667]
# 3612 [0.52229095 0.47770903]
# 3613 [0.5373499  0.46265012]
# 3615 [0.6125419 0.3874581]
# 3621 [0.62735844 0.37264156]
# 3623 [0.8944631  0.10553689]
# 3640 [0.51793486 0.48206508]
# 3656 [0.51804996 0.48195007]
# 3657 [0.52597433 0.47402564]
# 3662 [0.71545917 0.2845408 ]
# 3667 [0.505524   0.49447605]
# 3673 [0.60387087 0.3961292 ]
# 3696 [0.86178255 0.13821745]
# 3698 [0.5919513 0.4080487]
# 3703 [0.5691725  0.43082744]
# 3707 [0.7139708  0.28602928]
# 3710 [0.542751   0.45724896]
# 3728 [0.5331741 0.4668259]
# 3729 [0.5172155  0.48278448]
# 3731 [0.7449116  0.25508842]
# 3733 [0.7519601 0.2480399]
# 3742 [0.50058013 0.4994199 ]
# 3745 [0.6929543  0.30704573]
# 3755 [0.57023674 0.42976326]
# 3759 [0.92351407 0.07648595]
# 3777 [0.6028121 0.3971879]
# 3781 [0.6570014  0.34299865]
# 3782 [0.64942586 0.35057408]
# 3783 [0.8773877  0.12261236]
# 3793 [0.6931553  0.30684477]
# 3794 [0.85409    0.14591001]
# 3797 [0.7041089 0.2958912]
# 3804 [0.793516   0.20648408]
# 3805 [0.79481804 0.205182  ]
# 3812 [0.6697745  0.33022556]
# 3815 [0.6640741 0.3359259]
# 3824 [0.5068152  0.49318486]
# 3838 [0.7422711  0.25772887]
# 3839 [0.57955855 0.4204415 ]
# 3845 [0.50972986 0.4902701 ]
# 3850 [0.69961315 0.30038682]
# 3851 [0.73697495 0.26302502]
# 3853 [0.50405866 0.4959413 ]
# 3855 [0.908326   0.09167396]
# 3857 [0.5344622  0.46553785]
# 3864 [0.5098104  0.49018958]
# 3878 [0.71044064 0.2895594 ]
# 3885 [0.65337235 0.34662774]
# 3888 [0.6135033  0.38649666]
# 3889 [0.66213965 0.33786038]
# 3890 [0.82338285 0.17661719]
# 3892 [0.5822431 0.4177569]
# 3897 [0.7835975  0.21640247]
# 3905 [0.63200086 0.3679991 ]
# 3914 [0.82003415 0.17996584]
# 3918 [0.6386094  0.36139056]
# 3922 [0.7402981 0.2597019]
# 3937 [0.50541806 0.49458185]
# 3947 [0.87374115 0.12625882]
# 3950 [0.62219924 0.37780076]
# 3953 [0.9223763  0.07762374]
# 3963 [0.5970392 0.4029608]
# 3974 [0.5798346 0.4201654]
# 3981 [0.8871283  0.11287168]
# 3983 [0.84387434 0.1561257 ]
# 3984 [0.7035755  0.29642454]
# 3986 [0.73370486 0.26629505]
# 3992 [0.8578547  0.14214522]
# 3995 [0.6512385  0.34876153]
# 4004 [0.58031696 0.41968298]
# 4016 [0.63068646 0.36931354]
# 4023 [0.5538051 0.4461949]
# 4024 [0.6410485  0.35895148]
# 4029 [0.7254607  0.27453935]
# 4038 [0.83962005 0.16037995]
# 4051 [0.5078113 0.4921887]
# 4059 [0.7208577  0.27914232]
# 4066 [0.5117325  0.48826745]
# 4067 [0.5946846 0.4053154]
# 4075 [0.7763482  0.22365184]
# 4080 [0.80709034 0.19290966]
# 4083 [0.7090867  0.29091325]
# 4086 [0.86875683 0.13124314]
# 4089 [0.62806714 0.3719328 ]
# 4096 [0.7700765  0.22992352]
# 4101 [0.9087654  0.09123465]
# 4107 [0.6983365  0.30166346]
# 4117 [0.80385476 0.19614519]
# 4118 [0.53358454 0.46641544]
# 4119 [0.7287399  0.27126008]
# 4122 [0.5288801 0.4711199]
# 4133 [0.58120006 0.41879997]
# 4138 [0.88799655 0.11200345]
# 4148 [0.5123713 0.4876287]
# 4149 [0.7638853  0.23611465]
# 4150 [0.7152797 0.2847203]
# 4156 [0.598616   0.40138397]
# 4157 [0.6201932  0.37980676]
# 4163 [0.55203456 0.44796538]
# 4166 [0.6812193  0.31878066]
# 4172 [0.8256734  0.17432663]
# 4173 [0.7719675  0.22803244]
# 4180 [0.6077556 0.3922444]
# 4181 [0.60320055 0.39679947]
# 4184 [0.68384266 0.31615737]
# 4185 [0.80764997 0.19235006]
# 4198 [0.6353717  0.36462826]
# 4208 [0.6350677  0.36493233]
# 4212 [0.74146056 0.25853947]
# 4213 [0.82803106 0.17196889]
# 4214 [0.79132557 0.20867445]
# 4226 [0.75299436 0.24700563]
# 4227 [0.62747353 0.37252656]
# 4239 [0.59616196 0.40383807]
# 4259 [0.8128856  0.18711436]
# 4266 [0.6537332  0.34626684]
# 4269 [0.9009084  0.09909161]
# 4277 [0.50729614 0.49270386]
# 4288 [0.5213313  0.47866866]
# 4289 [0.80329484 0.19670512]
# 4291 [0.5635397 0.4364603]
# 4293 [0.8157707  0.18422933]
# 4295 [0.5030129  0.49698716]
# 4302 [0.7952676  0.20473248]
# 4307 [0.8705959 0.1294042]
# 4320 [0.62374455 0.37625542]
# 4357 [0.74523276 0.2547673 ]
# 4358 [0.69300807 0.30699196]
# 4368 [0.51566637 0.48433366]
# 4371 [0.67231756 0.3276824 ]
# 4384 [0.7251119  0.27488813]
# 4385 [0.5482943 0.4517057]
# 4394 [0.8514578 0.1485422]
# 4402 [0.7867746  0.21322538]
# 4404 [0.5035361  0.49646395]
# 4406 [0.5991769  0.40082318]
# 4411 [0.727463 0.272537]
# 4414 [0.6412035  0.35879648]
# 4433 [0.7638656 0.2361344]
# 4441 [0.5976347 0.4023654]
# 4442 [0.7042084 0.2957917]
# 4443 [0.52982104 0.4701789 ]
# 4447 [0.7943293  0.20567077]
# 4457 [0.7643151  0.23568486]
# 4463 [0.5865295  0.41347054]
# 4468 [0.57764477 0.4223552 ]
# 4472 [0.64936477 0.35063523]
# 4475 [0.6749424  0.32505757]
# 4480 [0.5513407  0.44865933]
# 4488 [0.75218314 0.24781692]
# 4504 [0.6573036 0.3426964]
# 4510 [0.8381548  0.16184515]
# 4511 [0.59451 0.40549]
# 4513 [0.73681223 0.26318777]
# 4514 [0.6599424 0.3400576]
# 4517 [0.79707855 0.20292142]
# 4519 [0.5768298 0.4231702]
# 4547 [0.68092614 0.31907383]
# 4561 [0.5671043  0.43289575]
# 4581 [0.7691927  0.23080726]
# 4587 [0.6938335 0.3061666]
# 4594 [0.56279945 0.43720052]
# 4598 [0.7355332  0.26446682]
# 4612 [0.5536081  0.44639188]
# 4613 [0.5889293  0.41107062]
# 4618 [0.6609485  0.33905146]

# %%
y_test[:10]
# Out:
# [1, 1, 1, 1, 1, 1, 1, 1, 1, 0]

# %%
y_test_one_hot[0]
# Out:
# array([0., 1.], dtype=float32)

# %%
words_dic_reverse = {}
for key in words_dic:
    words_dic_reverse[words_dic[key]]=key

# %%
words_dic_reverse[0]
# Out:
# '영화'

# %%
# Test data의 첫번째 리뷰
for index in X_test[0]:
    print(words_dic_reverse[index])
# Out:
# 좀비
# 특성
# 인물
# 묘사
# 연출
# 스토리
# 모두
# 부산
# 행
# 배
# 됨
# 진짜
# 재밌다

# %%
for index in X_test[4]:
    print(words_dic_reverse[index])
# Out:
# 감사합
# 너무
# 잘
# 봤

# %%
for index in X_test[0]:
    print(words_index_dic[index])
# Out:
# 좀비
# 특성
# 인물
# 묘사
# 연출
# 스토리
# 모두
# 부산
# 행
# 배
# 됨
# 진짜
# 재밌다
